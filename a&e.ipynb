# %%
# Import python libraries (using Python 3.8)
#------------------------------------------

import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import urllib.request
import zipfile
import networkx as nx
import osmnx as ox
import geopandas as gpd
import folium
import requests, json
from descartes import PolygonPatch
from shapely.geometry import Point, LineString, Polygon
from shapely.ops import cascaded_union
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from bs4 import BeautifulSoup
plt.style.use('ggplot')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
warnings.simplefilter('ignore')

# %%
#Read in the hospitals dataset. This is also freely available here https://www.nhs.uk/about-us/nhs-website-datasets/
#-------------------------------------------------------------------------------------------------------------------

hospital = pd.read_csv('/Users/paul.carroll/Github/nhs_time_of_travel/data/Hospital.csv', sep = ',')
hospital.head(2)
# Out:
#    OrganisationID OrganisationCode OrganisationType   SubType  \
# 0           17970            NDA07         Hospital  Hospital
# 1           17981            NDA18         Hospital  Hospital
#
#                Sector OrganisationStatus  IsPimsManaged  \
# 0  Independent Sector            Visible           True
# 1  Independent Sector            Visible           True
#
#                                     OrganisationName Address1        Address2  \
# 0  Walton Community Hospital - Virgin Care Servic...      NaN     Rodney Road
# 1            Woking Community Hospital (Virgin Care)      NaN  Heathside Road
#
#    ...  County  Postcode   Latitude Longitude  ParentODSCode  \
# 0  ...  Surrey  KT12 3LD  51.379997 -0.406042            NDA
# 1  ...  Surrey  GU22 7HS  51.315132 -0.556289            NDA
#
#                  ParentName         Phone Email Website           Fax,,,
# 0  Virgin Care Services Ltd  01932 414205   NaN     NaN  01932 253674,,,
# 1  Virgin Care Services Ltd  01483 715911   NaN     NaN              ,,,
#
# [2 rows x 22 columns]

# %%
#Some preparatory eda to organise and select the columns for the folium map
#--------------------------------------------------------------------------

hospital = hospital[(hospital['ParentName'].str.contains ('Lincolnshire'))].reset_index(drop = True)
hospital['Address'] = hospital[['Address2', 'Address3', 'County',]].astype(str).agg(', '.join, axis=1)
hospital['Address'] = hospital['Address'].str.title() + ', ' + hospital['Postcode']
hospital['Address'] = hospital['Address'].str.replace('Nan', '').str.replace(' ,', ' ')
hospital['Name'] = hospital['OrganisationName'].str.title()
hospital = hospital[['OrganisationCode', 'Name', 'Address', 'Postcode', 'Phone','ParentName','Latitude','Longitude']]

# %%
#Selecting the 4 24 hour A&E departments in Lincolnshire
#-------------------------------------------------------

hospital1 = hospital[hospital['Name'].str.contains('Pilgrim|Lincoln County|Diana, Princess|Scunthorpe')]

# %%
# Map visulation of Lincolnshire 24 hour A&E Departments
#-------------------------------------------------------

frame = folium.Figure(width=500, height=500)
folium_fig = folium.Map(
    location=[53.2, -0.3],
    tiles="cartodbpositron",
    zoom_start=8).add_to(frame)
for code, name, address, number, lat, lon in zip(hospital1['OrganisationCode'],
hospital1['Name'],
hospital1['Address'],
hospital1['Phone'],
hospital1['Latitude'],
hospital1['Longitude']):
    folium.Marker(
        [lat, lon],
        popup = folium.Popup('<b>' + 'Name: ' + '</b>'  + str(name) + '<br>'
        '<b>' + 'OrganisationCode: ' + '</b>' + str(code) + '<br>'
        '<b>' + 'Address: ' + '</b>' + str(address) + '<br>'
        '<b>' + 'Telephone Number: ' + '</b>' + str(number) + '<br>',
        max_width=len(address)*20),
        icon=folium.Icon(color="green", prefix='fa', icon="fa-medkit"),
        ).add_to(folium_fig)

folium_fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_260219b90f8842937d7569620f24defc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_260219b90f8842937d7569620f24defc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_260219b90f8842937d7569620f24defc = L.map(
#                 &quot;map_260219b90f8842937d7569620f24defc&quot;,
#                 {
#                     center: [53.2, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3becb6fabd9c22ae3b8219264599571 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_260219b90f8842937d7569620f24defc);
#
#
#             var marker_3fbf71315126b6104322b636495d176a = L.marker(
#                 [53.54485702514648, -0.0962134972214699],
#                 {}
#             ).addTo(map_260219b90f8842937d7569620f24defc);
#
#
#             var icon_be8e954c8a1893dafcfd0207d865a98d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-medkit&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3fbf71315126b6104322b636495d176a.setIcon(icon_be8e954c8a1893dafcfd0207d865a98d);
#
#
#         var popup_2331cd1b4712c8bfbdca767b8be6aaaa = L.popup({&quot;maxWidth&quot;: 240});
#
#
#             var html_5a7ca6c791200ffd02aeb5aa9c369520 = $(`&lt;div id=&quot;html_5a7ca6c791200ffd02aeb5aa9c369520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Name: &lt;/b&gt;Diana, Princess Of Wales Hospital&lt;br&gt;&lt;b&gt;OrganisationCode: &lt;/b&gt;RJL30&lt;br&gt;&lt;b&gt;Address: &lt;/b&gt;,   DN33 2BA&lt;br&gt;&lt;b&gt;Telephone Number: &lt;/b&gt;01472 874111&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_2331cd1b4712c8bfbdca767b8be6aaaa.setContent(html_5a7ca6c791200ffd02aeb5aa9c369520);
#
#
#         marker_3fbf71315126b6104322b636495d176a.bindPopup(popup_2331cd1b4712c8bfbdca767b8be6aaaa)
#         ;
#
#
#
#
#             var marker_6c737da29db22b9254bfada367cf50a7 = L.marker(
#                 [53.58758544921875, -0.6675840616226196],
#                 {}
#             ).addTo(map_260219b90f8842937d7569620f24defc);
#
#
#             var icon_69af20ef9c878bcd3abbe152439dd20b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-medkit&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6c737da29db22b9254bfada367cf50a7.setIcon(icon_69af20ef9c878bcd3abbe152439dd20b);
#
#
#         var popup_124be963cf1182a08bf3ed75d4edd22e = L.popup({&quot;maxWidth&quot;: 240});
#
#
#             var html_32a752c122642664eda274caf945ccba = $(`&lt;div id=&quot;html_32a752c122642664eda274caf945ccba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Name: &lt;/b&gt;Scunthorpe General Hospital&lt;br&gt;&lt;b&gt;OrganisationCode: &lt;/b&gt;RJL32&lt;br&gt;&lt;b&gt;Address: &lt;/b&gt;,   DN15 7BH&lt;br&gt;&lt;b&gt;Telephone Number: &lt;/b&gt;01724 282282&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_124be963cf1182a08bf3ed75d4edd22e.setContent(html_32a752c122642664eda274caf945ccba);
#
#
#         marker_6c737da29db22b9254bfada367cf50a7.bindPopup(popup_124be963cf1182a08bf3ed75d4edd22e)
#         ;
#
#
#
#
#             var marker_3429b41d08f090a3b302a9989f26c24f = L.marker(
#                 [53.23357772827149, -0.5196201801300049],
#                 {}
#             ).addTo(map_260219b90f8842937d7569620f24defc);
#
#
#             var icon_10b5c83bd1e27ce078692f36ee84a0be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-medkit&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3429b41d08f090a3b302a9989f26c24f.setIcon(icon_10b5c83bd1e27ce078692f36ee84a0be);
#
#
#         var popup_36e477bc2d476ccf7ad029527941e57f = L.popup({&quot;maxWidth&quot;: 480});
#
#
#             var html_79c94f47e853a40350b4f13a8853ab57 = $(`&lt;div id=&quot;html_79c94f47e853a40350b4f13a8853ab57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Name: &lt;/b&gt;Lincoln County Hospital&lt;br&gt;&lt;b&gt;OrganisationCode: &lt;/b&gt;RWDDA&lt;br&gt;&lt;b&gt;Address: &lt;/b&gt;,  Lincolnshire, LN2 5QY&lt;br&gt;&lt;b&gt;Telephone Number: &lt;/b&gt;01522 512512&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_36e477bc2d476ccf7ad029527941e57f.setContent(html_79c94f47e853a40350b4f13a8853ab57);
#
#
#         marker_3429b41d08f090a3b302a9989f26c24f.bindPopup(popup_36e477bc2d476ccf7ad029527941e57f)
#         ;
#
#
#
#
#             var marker_66daddb

# %%
# Enter your Google CP api key here 
#------------------------

api_key = "your api key here"

# %%
# Search code, that when run brings up an input box
# Then run this cell
# Then type in your search 
# The output will return the name, latitude and longitude
# My search was 'Urgent Care Centre Lincolnshire', to see what next level care there may be after A & E. 


key = api_key

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

query = input('Search query:')
  
r = requests.get(url + 'query=' + query +
                        '&key=' + key)

x = r.json()
  
y = x['results']
  
for i in range(len(y)):
    print(y[i]['name'],y[i]['geometry']['location']['lat'], y[i]['geometry']['location']['lng'])
# Out:
# Lincoln Urgent Treatment Centre 53.2339539 -0.5195115
# Skegness Urgent Treatment Centre 53.1451456 0.3321511
# Lincoln County Hospital Accident and Emergency 53.2339139 -0.5188239
# Urgent Care Centre 53.06742999999999 -0.8067749
# Grantham and District Hospital: Accident and Emergency Department 52.9201216 -0.6420511
# Skegness and District General Hospital 53.1450348 0.3325575000000001
# Johnson Community Hospital 52.8018247 -0.1502238
# Grantham and District Hospital 52.9210011 -0.6406482
# Sleaford Medical Group 52.9979453 -0.4063644
# John Coupland Hospital 53.4118799 -0.7847
# Lincoln County Hospital 53.2335711 -0.519479
# County Hospital Louth 53.3702224 -0.0084531
# Stamford and Rutland Hospital 52.656112 -0.467034
# East Lincolnshire Primary Care Trust Health Visitors 53.1822805 -0.5607525
# Pilgrim Hospital 52.9907719 -0.0106477
# Urgent Treatment Centre - Goole Hospital 53.7157176 -0.8741329999999999
# Newark Hospital 53.0677058 -0.806459
# Stark Lincolnshire & Goole Hospitals N H S Trust 53.6179873 -0.2059008

# %%
# This cell takes the output from the search above and populates a dataframe with Name, Latitude and Longitude 
#-------------------------------------------------------------------------------------------------------------

df = pd.DataFrame(y,columns=['name','geometry'])
df['Name'] = pd.DataFrame([x for x in df['name']])
df['location'] = pd.DataFrame([x for x in df['geometry']])['location']
df['Latitude'] = pd.DataFrame([x for x in df['location']])['lat']
df['Longitude'] = pd.DataFrame([x for x in df['location']])['lng']
df= df.drop(columns=['name','geometry','location'], axis=1)

# %%
# This is an example where the search results overlay the first folium map results 
#---------------------------------------------------------------------------------

frame = folium.Figure(width=500, height=500)
f_map = folium.Map([53.2, -0.3], zoom_start=8,  tiles="cartodbpositron").add_to(frame)
df.apply(lambda row: folium.CircleMarker(location=[row["Latitude"], row["Longitude"]], 
                                              radius=10, popup=row['Name'])
                                             .add_to(f_map), axis=1)

for code, name, address, number, lat, lon in zip(hospital1['OrganisationCode'],
hospital1['Name'],
hospital1['Address'],
hospital1['Phone'],
hospital1['Latitude'],
hospital1['Longitude']):
    folium.Marker(
        [lat, lon],
        popup = folium.Popup('<b>' + 'Name: ' + '</b>'  + str(name) + '<br>'
        '<b>' + 'OrganisationCode: ' + '</b>' + str(code) + '<br>'
        '<b>' + 'Address: ' + '</b>' + str(address) + '<br>'
        '<b>' + 'Telephone Number: ' + '</b>' + str(number) + '<br>',
        max_width=len(address)*20),
        icon=folium.Icon(color="green", prefix='fa', icon="fa-medkit"),
        ).add_to(f_map)

f_map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a326f6c80040a94966e4c602fe33f45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a326f6c80040a94966e4c602fe33f45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1a326f6c80040a94966e4c602fe33f45 = L.map(
#                 &quot;map_1a326f6c80040a94966e4c602fe33f45&quot;,
#                 {
#                     center: [53.2, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b55a661e3daf6ac3de3c2d2c8082b126 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a326f6c80040a94966e4c602fe33f45);
#
#
#             var circle_marker_ab16d8d44511b8858e8c943d1f69b4d5 = L.circleMarker(
#                 [53.2339539, -0.5195115],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a326f6c80040a94966e4c602fe33f45);
#
#
#         var popup_0db6e14e4b2e4fe8c9596ff3ba892605 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ea0f98357cccc57d32d6d78e1cc6d382 = $(`&lt;div id=&quot;html_ea0f98357cccc57d32d6d78e1cc6d382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln Urgent Treatment Centre&lt;/div&gt;`)[0];
#             popup_0db6e14e4b2e4fe8c9596ff3ba892605.setContent(html_ea0f98357cccc57d32d6d78e1cc6d382);
#
#
#         circle_marker_ab16d8d44511b8858e8c943d1f69b4d5.bindPopup(popup_0db6e14e4b2e4fe8c9596ff3ba892605)
#         ;
#
#
#
#
#             var circle_marker_3e9c87d1f64fb86daa7af63ee27b195d = L.circleMarker(
#                 [53.1451456, 0.3321511],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a326f6c80040a94966e4c602fe33f45);
#
#
#         var popup_2436cb7f7641d582ba8cd99d2c79d3fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_52d7172612bc537564a9d3eecfdfb671 = $(`&lt;div id=&quot;html_52d7172612bc537564a9d3eecfdfb671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Skegness Urgent Treatment Centre&lt;/div&gt;`)[0];
#             popup_2436cb7f7641d582ba8cd99d2c79d3fb.setContent(html_52d7172612bc537564a9d3eecfdfb671);
#
#
#         circle_marker_3e9c87d1f64fb86daa7af63ee27b195d.bindPopup(popup_2436cb7f7641d582ba8cd99d2c79d3fb)
#         ;
#
#
#
#
#             var circle_marker_c451acde6d7a453647e084339ccdf5da = L.circleMarker(
#                 [53.2339139, -0.5188239],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a326f6c80040a94966e4c602fe33f45);
#
#
#         var popup_b0b8878e71da8980ad51ccfbb399bd92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_918c5eef3ef20545d8f4a515521f49ec = $(`&lt;div id=&quot;html_918c5eef3ef20545d8f4a515521f49ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln County Hospital Accident and Emergency&lt;/div&gt;`)[0];
#             popup_b0b8878e71da8980ad51ccfbb399bd92.setContent(html_918c5eef3ef20545d8f4a515521f49ec);
#
#
#         circle_marker_c451acde6d7a453647e084339ccdf5da.bindPopup(popup_b0b8878e71da8980ad51ccfbb399bd92)
#         ;
#
#
#
#
#             var circle_marker_ce6f5c9bfdfd42830f9aded632f242d3 = L.circleMarker(
#                 [53.06742999999999, -0.8067749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;ro

# %%
# !pip3 install pyrosm
import pyrosm
from pyrosm import OSM, get_data
osm = OSM(get_data("Lincolnshire"))
nodes, edges = osm.get_network(nodes=True)
G = osm.to_graph(nodes, edges, graph_type="networkx")
# Out:
# Requirement already satisfied: pyrosm in /Users/paul.carroll/newenv/lib/python3.8/site-packages (0.6.1)
# Requirement already satisfied: pyrobuf in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (0.9.3)
# Requirement already satisfied: pygeos in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (0.13)
# Requirement already satisfied: cykhash in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (2.0.0)
# Requirement already satisfied: setuptools>=18.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (56.0.0)
# Requirement already satisfied: geopandas>=0.8.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (0.11.1)
# Requirement already satisfied: python-rapidjson in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrosm) (1.9)
# Requirement already satisfied: packaging in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from geopandas>=0.8.0->pyrosm) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from geopandas>=0.8.0->pyrosm) (3.4.0)
# Requirement already satisfied: pandas>=1.0.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from geopandas>=0.8.0->pyrosm) (1.5.1)
# Requirement already satisfied: fiona>=1.8 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from geopandas>=0.8.0->pyrosm) (1.8.22)
# Requirement already satisfied: shapely<2,>=1.7 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from geopandas>=0.8.0->pyrosm) (1.8.5.post1)
# Requirement already satisfied: numpy>=1.13 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pygeos->pyrosm) (1.23.4)
# Requirement already satisfied: jinja2>=2.8 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrobuf->pyrosm) (3.1.2)
# Requirement already satisfied: cython>=0.23 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pyrobuf->pyrosm) (0.29.32)
# Requirement already satisfied: click>=4.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (8.1.3)
# Requirement already satisfied: munch in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (1.1.1)
# Requirement already satisfied: six>=1.7 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (1.16.0)
# Requirement already satisfied: attrs>=17 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (22.1.0)
# Requirement already satisfied: certifi in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8.0->pyrosm) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from jinja2>=2.8->pyrobuf->pyrosm) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pandas>=1.0.0->geopandas>=0.8.0->pyrosm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from pandas>=1.0.0->geopandas>=0.8.0->pyrosm) (2022.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/paul.carroll/newenv/lib/python3.8/site-packages (from packaging->geopandas>=0.8.0->pyrosm) (3.0.9)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/paul.carroll/newenv/bin/python3 -m pip install --upgrade pip' command.
# Downloaded Protobuf data 'lincolnshire-latest.osm.pbf' (32.7 MB) to:
# '/var/folders/91/dh1v62bs23d450jv1db1d1h40000gp/T/pyrosm/lincolnshire-latest.osm.pbf'

# %%
# Creates an OMSnx map of Lincolnshire, with the transport mode selected here as 'drive'.
'''
place = "Lincolnshire, England"
G = ox.graph_from_place(place, network_type="drive")
'''
ox.plot_graph(G);
fig, ax = ox.plot_graph(G);
#plt.tight_layout()
plt.show();

# %%
# combining the dataframes 
#-------------------------
hospital2 = hospital1[['Name','Latitude','Longitude']]
df_combined = hospital2.append(df)

# %%
# Map the dataframe coordinates onto the OSMnx nodes
#---------------------------------------------------

point_of_interest = ox.distance.nearest_nodes(G, X = df_combined['Longitude'], Y=df_combined['Latitude']) # X = longitude, Y = Latitude #------ nearest edge

# %%
#Defining trip times of interest, walking speed, and adding and edge attribute 'time' to each edge in urban network graph
#------------------------------------------------------------------------------------------------------------------------
# Trip time in Mintues
trip_times = [10,20,30]

# transport speed in km/hour
travel_speed = 60

# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60 #km per hour to m per minute
for u, v, k, data in G.edges(data=True, keys=True):
    data['time'] = data['length'] / meters_per_minute

#---------------
# u,v,k refer to the unique indentifiers of an edge in a network graph. u and v are the two nodes the edege connects while the k, is the key attribute which differentiates between parallel edges. 
# data refers to edge attributes - these include length, osmid, oneway and others

# 1 - get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap='Reds', start=0.3, return_hex=True)
# 2 - color the nodes according to isochrone then plot the street network
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    for points in point_of_interest:
        subgraph = nx.ego_graph(G, points, radius=trip_time, distance='time')
        for node in subgraph.nodes():
            node_colors[node] = color
nc = [node_colors[node] if node in node_colors else 'none' for node in G.nodes()]
ns = [10 if node in node_colors else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(G, node_color=nc, node_size=ns, node_alpha=0.8, node_zorder=2)

# make the isochrone polygons
#----------------------------
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    isochrone_polys_sub = []
    for points in point_of_interest:
        subgraph = nx.ego_graph(G, points, radius=trip_time, distance='time')
        node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
        bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
        isochrone_polys_sub.append(bounding_poly)
    isochrone_polys.append(isochrone_polys_sub)

# plot the network then add isochrones as colored descartes polygon patches
#--------------------------------------------------------------------------
fig, ax = ox.plot_graph(G, show=False, close=False, edge_color='k', edge_alpha=0.2, node_color='none')
for polygon, fc in zip(isochrone_polys, iso_colors):
    for subpolygon in polygon:
        patch = PolygonPatch(subpolygon, fc=fc, ec='none', alpha=0.6, zorder=-1)
        ax.add_patch(patch)
plt.show()

# %%
# Plot the travel time isochrones on top of the folium map

graph_map = ox.plot_graph_folium(G, f_map, color="#425563", opacity=0.5, weight=1)

style_geojson = [
{'shape_name': '30 min drive','shape_fillColor': '#003087'},
{'shape_name': '20 min drive', 'shape_fillColor': '#005EB8'},
{'shape_name': '10 min drive', 'shape_fillColor': '#41B6E6'}]
gdf_index = list(df_combined.index)
for polygon, style in zip(isochrone_polys, style_geojson):
     gdf = gpd.GeoDataFrame({"24Hour A&E": gdf_index}, geometry= polygon)
     polygon_json = list(gdf['geometry'])
     geojson = gpd.GeoSeries(cascaded_union(polygon_json)).to_json()
     fillColor = style['shape_fillColor']
     shape_name = style['shape_name']
     folium.GeoJson(geojson, name = shape_name, style_function = lambda x, fillColor = fillColor: {
            "fillColor": fillColor,
            "name":  shape_name,
            "weight": 1,
            "fillOpacity": 0.5,
            "color": "#000000"
            }).add_to(f_map)

folium.LayerControl().add_to(f_map)
f_map
